# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

# Load the dataset (replace with your liver dataset)
url = '/content/dataset_med.csv'
column_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
data = pd.read_csv(url, header=None, names=column_names)

print(data.head())
# Out:
#                                                                                      Pregnancies  \
# id age  gender country     diagnosis_date cancer_stage family_history smoking_status         bmi
# 1  64.0 Male   Sweden      2016-04-05     Stage I      Yes            Passive Smoker        29.4
# 2  50.0 Female Netherlands 2023-04-20     Stage III    Yes            Passive Smoker        41.2
# 3  65.0 Female Hungary     2023-04-05     Stage III    Yes            Former Smoker         44.0
# 4  51.0 Female Belgium     2016-02-05     Stage I      No             Passive Smoker        43.0
#
#                                                                                                 Glucose  \
# id age  gender country     diagnosis_date cancer_stage family_history smoking_status  cholesterol_level
# 1  64.0 Male   Sweden      2016-04-05     Stage I      Yes            Passive Smoker                199
# ...

# %%
import pandas as pd

# Load the dataset (replace with your liver dataset)
url = '/content/dataset_med.csv'
column_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']
data = pd.read_csv(url, header=None, names=column_names)  # Assuming no header row in your CSV

# Check for non-numeric values in the 'BMI' column
# This will print any rows where the 'BMI' column is not numeric
print(data[pd.to_numeric(data['BMI'], errors='coerce').isnull()])

# Replace or remove the non-numeric values in the 'BMI' column
# Option 1: Replace non-numeric values with NaN and then impute
data['BMI'] = pd.to_numeric(data['BMI'], errors='coerce')  # Convert to numeric, invalid values become NaN
data['BMI'].fillna(data['BMI'].mean(), inplace=True)  # Fill NaN with the mean of the column

# Option 2: Remove rows with non-numeric values
# data = data[pd.to_numeric(data['BMI'], errors='coerce').notnull()]

print(data.head())
# Out:
# <ipython-input-20-4a7e01f55f60>:6: DtypeWarning: Columns (0,1,8,9,10,11,12,13,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(url, header=None, names=column_names)  # Assuming no header row in your CSV
#                                                                                      Pregnancies  ...   Outcome
# id     age  gender country diagnosis_date cancer_stage family_history smoking_status         bmi  ...  survived
# 739744 60.0 Male   Sweden  NaN            NaN          NaN            NaN                    NaN  ...       NaN
#
# [2 rows x 9 columns]
#                                                                                      Pregnancies  ...   Outcome
# id age  gender country     diagnosis_date cancer_stage family_history smoking_status         bmi  ...  survived
# 1  64.0 Male   Sweden      2016-04-05     Stage I      Yes            Passive Smoker        29.4  ...         0
# ...

# %%
print(data.head())
# Out:
#                                                                                       Pregnancies  \
# id age  gender country     diagnosis_date cancer_stage family_history smoking_status    30.584191
# 1  64.0 Male   Sweden      2016-04-05     Stage I      Yes            Passive Smoker    29.400000
# 2  50.0 Female Netherlands 2023-04-20     Stage III    Yes            Passive Smoker    41.200000
# 3  65.0 Female Hungary     2023-04-05     Stage III    Yes            Former Smoker     44.000000
# 4  51.0 Female Belgium     2016-02-05     Stage I      No             Passive Smoker    43.000000
#
#                                                                                         Glucose  \
# id age  gender country     diagnosis_date cancer_stage family_history smoking_status  234.14837
# 1  64.0 Male   Sweden      2016-04-05     Stage I      Yes            Passive Smoker  199.00000
# 2  50.0 Female Netherlands 2023-04-20     Stage III    Yes            Passive Smoker  280.00000
# ...

# %%
print(data.isnull().sum())
x = data.drop('Outcome', axis=1)

y = data['Outcome']
# Out:
# Pregnancies                 1
# Glucose                     1
# BloodPressure               1
# SkinThickness               1
# Insulin                     1
# BMI                         1
# DiabetesPedigreeFunction    1
# Age                         1
# Outcome                     1
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor  # Import Regressor instead of Classifier

# ... (your previous code to load and preprocess data) ...

# Assuming your DataFrame is named 'data'
# Convert 'BMI' column to numeric, handling errors
data['BMI'] = pd.to_numeric(data['BMI'], errors='coerce')
# Fill NaN values in 'BMI' column with the mean of 'BMI' column
data['BMI'] = data['BMI'].fillna(data['BMI'].mean())

# Check for any remaining non-numeric values in the DataFrame
for column in data.columns:
    if data[column].dtype == object:  # Check if the column is of object type (likely string)
        # Attempt to convert the column to numeric
        try:
            data[column] = pd.to_numeric(data[column], errors='coerce')
            # Fill any resulting NaN values with the column's mean
            data[column] = data[column].fillna(data[column].mean())
        except ValueError:
            print(f"Warning: Column '{column}' could not be converted to numeric and may contain problematic values.")

# Proceed with model training
x = data.drop('Outcome', axis=1)
y = data['Outcome']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# Change to RandomForestRegressor for continuous target variable
model = RandomForestRegressor(random_state=42)
model.fit(x_train, y_train)

# ... (rest of your code) ...
# Out:
# RandomForestRegressor(random_state=42)
